# %% [markdown]
# # Up to 3x higher Throughput for Llama using new Amazon SageMaker multi-replica endpoints
#
# One of the key announcements at this year's re:Invent (2023) was the new Hardware Requirements object for Amazon SageMaker endpoints. This provides granular control over the compute resources for each model replica, including minimum CPU, GPU, memory, and number of replicas. This allows you to optimize your model's throughput and cost by matching the compute resources to the model's requirements. Previously it was not possible to deploy multiple replicas of a model on a single endpoint, which limited the throughput of models that were not compute bound, e.g. open LLMs like Llama 13B on p4d.24xlarge instances.
#
# In this post, we show how to use the new Hardware Requirements as with the sagemaker sdk and the `ResourceRequirements` object to optimize the deployment of Llama 13B for maximum throughput and cost performance on Amazon SageMaker on a `p4d.24xlarge` instance. The `p4d.24xlarge` instance has 8x A100 GPUs 40GB, which allows us to deploy 8 replicas of Llama 13B on a single instance. You can also use this example to deploy other open LLMs like Mistral, T5 or StarCoder. Additionally it is possible to deploy multiple models on a single instance, e.g. 4x Llama 13B and 4x Mistral 1.3B. Check out the amazing [blog post from Antje for this](https://aws.amazon.com/de/blogs/aws/amazon-sagemaker-adds-new-inference-capabilities-to-help-reduce-foundation-model-deployment-costs-and-latency/).
#
# We are going to use the Hugging Face LLM DLC is a new purpose-built Inference Container to easily deploy LLMs in a secure and managed environment. The DLC is powered by [Text Generation Inference (TGI)](https://github.com/huggingface/text-generation-inference) a scalelable, optimized solution for deploying and serving Large Language Models (LLMs). The Blog post also includes Hardware requirements for the different model sizes.
#
# In the blog will cover how to:
# 1. [Setup development environment](#1-setup-development-environment)
# 2. [Retrieve the new Hugging Face LLM DLC](#2-retrieve-the-new-hugging-face-llm-dlc)
# 3. [Configure Hardware requirements per replica](#3-configure-hardware-requirements-per-replica)
# 4. [Deploy and Test Llama 2 on Amazon SageMaker](#4-deploy-llama-2-to-amazon-sagemaker)
# 5. [Run performance a simple performance benchmark](#5-benchmark-multi-replica-endpoint)
#
# Lets get started!

# %% [markdown]
# ## 1. Setup development environment
#
# We are going to use the `sagemaker` python SDK to deploy Llama 2 to Amazon SageMaker. We need to make sure to have an AWS account configured and the `sagemaker` python SDK installed.

# %%
# !pip install "sagemaker>=2.199.0" "transformers==4.35.2" --upgrade --quiet

# %% [markdown]
# If you are going to use Sagemaker in a local environment. You need access to an IAM Role with the required permissions for Sagemaker. You can find [here](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-roles.html) more about it.

# %%
import sagemaker
import boto3
sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

try:
    role = sagemaker.get_execution_role()
except ValueError:
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# Couldn't call 'get_role' to get Role ARN from role name philippschmid to get Role path.
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# sagemaker role arn: arn:aws:iam::558105141721:role/sagemaker_execution_role
# sagemaker session region: us-east-1

# %% [markdown]
# ## 2. Retrieve the new Hugging Face LLM DLC
#
# Compared to deploying regular Hugging Face models we first need to retrieve the container uri and provide it to our `HuggingFaceModel` model class with a `image_uri` pointing to the image. To retrieve the new Hugging Face LLM DLC in Amazon SageMaker, we can use the `get_huggingface_llm_image_uri` method provided by the `sagemaker` SDK. This method allows us to retrieve the URI for the desired Hugging Face LLM DLC based on the specified `backend`, `session`, `region`, and `version`. You can find the available versions [here](https://github.com/aws/deep-learning-containers/blob/master/available_images.md#huggingface-text-generation-inference-containers)

# %%
from sagemaker.huggingface import get_huggingface_llm_image_uri

# retrieve the llm image uri
llm_image = get_huggingface_llm_image_uri(
  "huggingface",
  version="1.1.0"
)

# print ecr image uri
print(f"llm image uri: {llm_image}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# llm image uri: 763104351884.dkr.ecr.us-east-1.amazonaws.com/huggingface-pytorch-tgi-inference:2.0.1-tgi1.1.0-gpu-py39-cu118-ubuntu20.04

# %% [markdown]
# ## 3. Configure Hardware requirements per replica
#
# Llama 2 comes in 3 different sizes - 7B, 13B & 70B parameters. The hardware requirements will vary based on the model size deployed to SageMaker. Below is an example configuration for Llama 13B. In addition we tried to provide some high level overview of the different hardware requirements for the different model sizes. To keep it simple we only looked at the `p4d.24xlarge` instance type and AWQ/GPTQ quantization.
#
# | Model                                                              | Instance Type       | Quantization | # replica |
# |--------------------------------------------------------------------|---------------------|--------------|-----------|
# | [Llama 7B](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf)   | `(ml.)p4d.24xlarge` | `-`          | 8         |
# | [Llama 7B](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf)   | `(ml.)p4d.24xlarge` | `GPTQ/AWQ`   | 8         |
# | [Llama 13B](https://huggingface.co/meta-llama/Llama-2-13b-chat-hf) | `(ml.)p4d.24xlarge` | `-`          | 8         |
# | [Llama 13B](https://huggingface.co/meta-llama/Llama-2-13b-chat-hf) | `(ml.)p4d.24xlarge` | `GPTQ/AWQ`   | 8         |
# | [Llama 70B](https://huggingface.co/meta-llama/Llama-2-70b-chat-hf) | `(ml.)p4d.24xlarge` | `-`          | 2         |
# | [Llama 70B](https://huggingface.co/meta-llama/Llama-2-70b-chat-hf) | `(ml.)p4d.24xlarge` | `GPTQ/AWQ`   | 4         |
#
#
# _We didn't test the configurations yet. If you run into errors please let me know and I will update the blog post._

# %%
from sagemaker.compute_resource_requirements.resource_requirements import ResourceRequirements

llama2_13b_resource_config = ResourceRequirements(
    requests = {
        "copies": 8, # Number of replicas
        "num_accelerators": 1, # Number of GPUs
        "num_cpus": 10,  # Number of CPU cores  96 // num_replica - more for management
        "memory": 100 * 1024,  # Minimum memory in MB 1152 // num_replica - more for management
    },
)

# %% [markdown]
# ## 4. Deploy Llama 2 to Amazon SageMaker
#
# To deploy [meta-llama/Llama-2-13b-chat-hf](https://huggingface.co/models?other=llama-2) to Amazon SageMaker we create a `HuggingFaceModel` model class and define our endpoint configuration including the `hf_model_id`, `instance_type` and then add our `ResourceRequirements` object to the `deploy` method.
#
# _Note: This is a form to enable access to Llama 2 on Hugging Face after you have been granted access from Meta. Please visit the [Meta website](https://ai.meta.com/resources/models-and-libraries/llama-downloads) and accept our license terms and acceptable use policy before submitting this form. Requests will be processed in 1-2 days. We alternatively use the ungated weights from `NousResearch/Llama-2-13b-chat-hf`._

# %%
import json
import uuid
from sagemaker.huggingface import HuggingFaceModel
from sagemaker.enums import EndpointType

# sagemaker config
instance_type = "ml.p4d.24xlarge"
health_check_timeout = 300

# Define Model and Endpoint configuration parameter
config = {
  'HF_MODEL_ID': "NousResearch/Llama-2-13b-chat-hf", # model_id from hf.co/models
  'SM_NUM_GPUS': json.dumps(1), # Number of GPU used per replica
  'MAX_INPUT_LENGTH': json.dumps(2048),  # Max length of input text
  'MAX_TOTAL_TOKENS': json.dumps(4096),  # Max length of the generation (including input text)
  'MAX_BATCH_TOTAL_TOKENS': json.dumps(16384),  # Limits the number of tokens that can be processed in parallel during the generation
  # 'HUGGING_FACE_HUB_TOKEN': "<REPLACE WITH YOUR TOKEN>" # uncomment when using a private model
  # ,'HF_MODEL_QUANTIZE': "gptq", # comment in when using awq quantized checkpoint

}

# create HuggingFaceModel with the image uri
llm_model = HuggingFaceModel(
  role=role,
  image_uri=llm_image,
  env=config,
)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml

# %% [markdown]
# After we have created the `HuggingFaceModel` we can deploy it to Amazon SageMaker using the `deploy` method using the `ResourceRequirements` object.

# %%
# Deploy model to an endpoint
# https://sagemaker.readthedocs.io/en/stable/api/inference/model.html#sagemaker.model.Model.deploy
llm = llm_model.deploy(
  initial_instance_count=1, # number of instances
  instance_type=instance_type, # base instance type
  resources=llama2_13b_resource_config, # resource config for multi-replica
  container_startup_health_check_timeout=health_check_timeout, # 10 minutes to be able to load the model
  endpoint_name=f"llama-2-13b-chat-{str(uuid.uuid4())}", # name needs to be unique
  endpoint_type=EndpointType.INFERENCE_COMPONENT_BASED # needed to use resource config
  
)
# Out:
# -----!----------------------------------------!

# %% [markdown]
# SageMaker will now create our endpoint and deploy the model to it. This can takes a 15-25 minutes, since the replicas are deployed after each other. After the endpoint is created we can use the `predict` method to send a request to our endpoint. To make it easier we will use the [apply_chat_template](apply_chat_template) method from transformers. This allow us to send "openai" like converstaions to our model.

# %%
from transformers import AutoTokenizer

tok = AutoTokenizer.from_pretrained(config["HF_MODEL_ID"])

# OpenAI like conversational messages
messages = [
  {"role": "system", "content": "You are an helpful AWS Expert Assistant. Respond only with 1-2 sentences."},
  {"role": "user", "content": "What is Amazon SageMaker?"},
]

# generation parameters
parameters = {
    "do_sample" : True,
    "top_p": 0.6,
    "temperature": 0.9,
    "top_k": 50,
    "max_new_tokens": 50,
    "repetition_penalty": 1.03,
    "return_full_text": False,
}

res = llm.predict(
  {
    "inputs": tok.apply_chat_template(messages, tokenize=False),
    "parameters": parameters
   })

print(res[0]['generated_text'].strip())
# Out:
# Sure, I'd be happy to help! Amazon SageMaker is a fully managed service that provides a range of machine learning (ML) capabilities, including data preparation, training, and deployment, to help you build, train,

# %%
import threading
import time
number_of_threads = 20
number_of_requests = int(1000 // number_of_threads)
print(f"number of threads: {number_of_threads}")
print(f"number of requests per thread: {number_of_requests}")

def send_rquests():
    for _ in range(number_of_requests):
        # input counted at https://huggingface.co/spaces/Xenova/the-tokenizer-playground for 100 tokens
        llm.predict({
    "inputs": tok.apply_chat_template(messages, tokenize=False),
    "parameters": parameters
   })

# Create multiple threads
threads = [threading.Thread(target=send_rquests) for _ in range(number_of_threads) ]
# start all threads
start = time.time()
[t.start() for t in threads]
# wait for all threads to finish
[t.join() for t in threads]
print(f"total time: {round(time.time() - start)} seconds")
# Out:
# number of threads: 20
# number of requests per thread: 50
# total time: 76 seconds

# %% [markdown]
# ## 5. Benchmark multi-replica endpoint
#
# To Benchmark our new endpoint we will use the same code as for the ["Llama 2 on Amazon SageMaker a Benchmark"](https://huggingface.co/blog/llama-sagemaker-benchmark) from [text-generation-inference-tests](https://github.com/philschmid/text-generation-inference-tests/tree/master/sagemaker_llm_container). When running the benchmark back then it was not possible to deploy multiple replicas of a model on a single endpoint. This limited the throughput of models that were not compute bound, e.g. open LLMs like Llama 13B on p4d.24xlarge instances.
#
# To run the benchmark we need to clone the [text-generation-inference-tests](https://github.com/philschmid/text-generation-inference-tests) and also make sure we meet all the `Prerequisites` from the [README](https://github.com/philschmid/text-generation-inference-tests/tree/master/sagemaker_llm_container), including the installation of [k6](https://k6.io/) which used to run the benchmark.

# %%
# !git clone https://github.com/philschmid/text-generation-inference-tests.git
# Out:
# Cloning into 'text-generation-inference-tests'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 176 (delta 98), reused 160 (delta 84), pack-reused 0
# Receiving objects: 100% (176/176), 670.64 KiB | 5.12 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %% [markdown]
# Since we already a deployed endpoint we can provide the `endpoint_name` and our hardware requirements as `inference_component`. The name of the `inference_component` can currently only be retrieved using `boto3`

# %%
inference_component = llm_model.sagemaker_session.list_inference_components(endpoint_name_equals=llm.endpoint_name).get("InferenceComponents")[0].get("InferenceComponentName")
endpoint_name = llm.endpoint_name

# %%
inference_component
# Out:
# 'huggingface-pytorch-tgi-inference-2023-12-08-08-1702025443-7ff6'

# %% [markdown]
# Change the directory to `sagemaker_llm_container` and run the benchmark. The command below will run a load test for 90s with 50 concurrent users. The result will be saved to `text-generation-inference-tests/sagemaker_llm_container/{CONIFG_NAME}.json`.

# %%
# !cd text-generation-inference-tests/sagemaker_llm_container && python benchmark.py \
  --endpoint_name {endpoint_name} \
  --inference_component {inference_component} \
  --model_id {config["HF_MODEL_ID"]} \
  --tp_degree 1 \
  --vu 20
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
# sagemaker role arn: arn:aws:iam::558105141721:role/sagemaker_execution_role
# token: None
# model id: NousResearch/Llama-2-13b-chat-hf
# instance type: None
# tp_degree: 1
# vu: 20
# quantize: None
# endpoint_name: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb
# inference_component: huggingface-pytorch-tgi-inference-2023-12-08-08-1702025443-7ff6
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
#
#           /\      |‾‾| /‾‾/   /‾‾/
#      /\  /  \     |  |/  /   /  /
#     /  \/    \    |     (   /   ‾‾\
#    /          \   |  |\  \ |  (‾)  |
#   / __________ \  |__| \__\ \_____/ .io
#
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
#   execution: local
#      script: sagemaker_load.js
#      output: -
#
#   scenarios: (100.00%) 1 scenario, 20 max VUs, 2m0s max duration (incl. graceful stop):
#            * test: 20 looping VUs for 1m30s (gracefulStop: 30s)
#
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
# INFO[0000] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
# INFO[0000] REGION: us-east-1                             source=console
#
# running (0m00.1s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.1s/1m30s
#
# running (0m00.2s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.2s/1m30s
#
# running (0m00.3s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.3s/1m30s
#
# running (0m00.4s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.4s/1m30s
#
# running (0m00.5s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.5s/1m30s
#
# running (0m00.6s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.6s/1m30s
#
# running (0m00.7s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.7s/1m30s
#
# running (0m00.8s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.8s/1m30s
#
# running (0m00.9s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m00.9s/1m30s
#
# running (0m01.0s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.0s/1m30s
#
# running (0m01.1s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.1s/1m30s
#
# running (0m01.2s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.2s/1m30s
#
# running (0m01.3s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.3s/1m30s
#
# running (0m01.4s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.4s/1m30s
#
# running (0m01.5s), 20/20 VUs, 0 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.5s/1m30s
#
# running (0m01.6s), 20/20 VUs, 17 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.6s/1m30s
#
# running (0m01.7s), 20/20 VUs, 17 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.7s/1m30s
#
# running (0m01.8s), 20/20 VUs, 17 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.8s/1m30s
#
# running (0m01.9s), 20/20 VUs, 17 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m01.9s/1m30s
#
# running (0m02.0s), 20/20 VUs, 17 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m02.0s/1m30s
#
# running (0m02.1s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m02.1s/1m30s
#
# running (0m02.2s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m02.2s/1m30s
#
# running (0m02.3s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [--------------------------------------] 20 VUs  0m02.3s/1m30s
#
# running (0m02.4s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.4s/1m30s
#
# running (0m02.5s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.5s/1m30s
#
# running (0m02.6s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.6s/1m30s
#
# running (0m02.7s), 20/20 VUs, 20 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.7s/1m30s
#
# running (0m02.8s), 20/20 VUs, 22 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.8s/1m30s
#
# running (0m02.9s), 20/20 VUs, 33 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m02.9s/1m30s
#
# running (0m03.0s), 20/20 VUs, 33 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.0s/1m30s
#
# running (0m03.1s), 20/20 VUs, 33 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.1s/1m30s
#
# running (0m03.2s), 20/20 VUs, 33 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.2s/1m30s
#
# running (0m03.3s), 20/20 VUs, 37 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.3s/1m30s
#
# running (0m03.4s), 20/20 VUs, 38 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.4s/1m30s
#
# running (0m03.5s), 20/20 VUs, 38 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.5s/1m30s
#
# running (0m03.6s), 20/20 VUs, 38 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.6s/1m30s
#
# running (0m03.7s), 20/20 VUs, 38 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.7s/1m30s
#
# running (0m03.8s), 20/20 VUs, 40 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.8s/1m30s
#
# running (0m03.9s), 20/20 VUs, 40 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m03.9s/1m30s
#
# running (0m04.0s), 20/20 VUs, 40 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.0s/1m30s
#
# running (0m04.1s), 20/20 VUs, 43 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.1s/1m30s
#
# running (0m04.2s), 20/20 VUs, 51 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.2s/1m30s
#
# running (0m04.3s), 20/20 VUs, 51 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.3s/1m30s
#
# running (0m04.4s), 20/20 VUs, 51 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.4s/1m30s
#
# running (0m04.5s), 20/20 VUs, 52 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.5s/1m30s
#
# running (0m04.6s), 20/20 VUs, 56 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.6s/1m30s
#
# running (0m04.7s), 20/20 VUs, 57 complete and 0 interrupted iterations
# test   [>-------------------------------------] 20 VUs  0m04.7s/1m30s
#
# running (0m04.8s), 20/20 VUs, 57 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m04.8s/1m30s
#
# running (0m04.9s), 20/20 VUs, 57 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m04.9s/1m30s
#
# running (0m05.0s), 20/20 VUs, 57 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.0s/1m30s
#
# running (0m05.1s), 20/20 VUs, 60 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.1s/1m30s
#
# running (0m05.2s), 20/20 VUs, 60 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.2s/1m30s
#
# running (0m05.3s), 20/20 VUs, 61 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.3s/1m30s
#
# running (0m05.4s), 20/20 VUs, 62 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.4s/1m30s
#
# running (0m05.5s), 20/20 VUs, 69 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.5s/1m30s
#
# running (0m05.6s), 20/20 VUs, 69 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.6s/1m30s
#
# running (0m05.7s), 20/20 VUs, 69 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.7s/1m30s
#
# running (0m05.8s), 20/20 VUs, 70 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.8s/1m30s
#
# running (0m05.9s), 20/20 VUs, 76 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m05.9s/1m30s
#
# running (0m06.0s), 20/20 VUs, 77 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.0s/1m30s
#
# running (0m06.1s), 20/20 VUs, 77 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.1s/1m30s
#
# running (0m06.2s), 20/20 VUs, 77 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.2s/1m30s
#
# running (0m06.3s), 20/20 VUs, 77 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.3s/1m30s
#
# running (0m06.4s), 20/20 VUs, 80 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.4s/1m30s
#
# running (0m06.5s), 20/20 VUs, 80 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.5s/1m30s
#
# running (0m06.6s), 20/20 VUs, 80 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.6s/1m30s
#
# running (0m06.7s), 20/20 VUs, 83 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.7s/1m30s
#
# running (0m06.8s), 20/20 VUs, 85 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.8s/1m30s
#
# running (0m06.9s), 20/20 VUs, 87 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m06.9s/1m30s
#
# running (0m07.0s), 20/20 VUs, 87 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m07.0s/1m30s
#
# running (0m07.1s), 20/20 VUs, 88 complete and 0 interrupted iterations
# test   [=>------------------------------------] 20 VUs  0m07.1s/1m30s
#
# running (0m07.2s), 20/20 VUs, 93 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.2s/1m30s
#
# running (0m07.3s), 20/20 VUs, 94 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.3s/1m30s
#
# running (0m07.4s), 20/20 VUs, 94 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.4s/1m30s
#
# running (0m07.5s), 20/20 VUs, 94 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.5s/1m30s
#
# running (0m07.6s), 20/20 VUs, 96 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.6s/1m30s
#
# running (0m07.7s), 20/20 VUs, 100 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.7s/1m30s
#
# running (0m07.8s), 20/20 VUs, 100 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.8s/1m30s
#
# running (0m07.9s), 20/20 VUs, 100 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m07.9s/1m30s
#
# running (0m08.0s), 20/20 VUs, 102 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.0s/1m30s
#
# running (0m08.1s), 20/20 VUs, 105 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.1s/1m30s
#
# running (0m08.2s), 20/20 VUs, 106 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.2s/1m30s
#
# running (0m08.3s), 20/20 VUs, 106 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.3s/1m30s
#
# running (0m08.4s), 20/20 VUs, 107 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.4s/1m30s
#
# running (0m08.5s), 20/20 VUs, 110 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.5s/1m30s
#
# running (0m08.6s), 20/20 VUs, 111 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.6s/1m30s
#
# running (0m08.7s), 20/20 VUs, 112 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.7s/1m30s
#
# running (0m08.8s), 20/20 VUs, 113 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.8s/1m30s
#
# running (0m08.9s), 20/20 VUs, 115 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m08.9s/1m30s
#
# running (0m09.0s), 20/20 VUs, 118 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m09.0s/1m30s
#
# running (0m09.1s), 20/20 VUs, 119 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m09.1s/1m30s
#
# running (0m09.2s), 20/20 VUs, 119 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m09.2s/1m30s
#
# running (0m09.3s), 20/20 VUs, 122 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m09.3s/1m30s
#
# running (0m09.4s), 20/20 VUs, 122 complete and 0 interrupted iterations
# test   [==>-----------------------------------] 20 VUs  0m09.4s/1m30s
#
# running (0m09.5s), 20/20 VUs, 125 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m09.5s/1m30s
#
# running (0m09.6s), 20/20 VUs, 125 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m09.6s/1m30s
#
# running (0m09.7s), 20/20 VUs, 126 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m09.7s/1m30s
#
# running (0m09.8s), 20/20 VUs, 128 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m09.8s/1m30s
#
# running (0m09.9s), 20/20 VUs, 131 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m09.9s/1m30s
#
# running (0m10.0s), 20/20 VUs, 131 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.0s/1m30s
#
# running (0m10.1s), 20/20 VUs, 134 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.1s/1m30s
#
# running (0m10.2s), 20/20 VUs, 134 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.2s/1m30s
#
# running (0m10.3s), 20/20 VUs, 136 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.3s/1m30s
#
# running (0m10.4s), 20/20 VUs, 139 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.4s/1m30s
#
# running (0m10.5s), 20/20 VUs, 139 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.5s/1m30s
#
# running (0m10.6s), 20/20 VUs, 139 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.6s/1m30s
#
# running (0m10.7s), 20/20 VUs, 140 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.7s/1m30s
#
# running (0m10.8s), 20/20 VUs, 145 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.8s/1m30s
#
# running (0m10.9s), 20/20 VUs, 145 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m10.9s/1m30s
#
# running (0m11.0s), 20/20 VUs, 145 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.0s/1m30s
#
# running (0m11.1s), 20/20 VUs, 146 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.1s/1m30s
#
# running (0m11.2s), 20/20 VUs, 148 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.2s/1m30s
#
# running (0m11.3s), 20/20 VUs, 151 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.3s/1m30s
#
# running (0m11.4s), 20/20 VUs, 151 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.4s/1m30s
#
# running (0m11.5s), 20/20 VUs, 153 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.5s/1m30s
#
# running (0m11.6s), 20/20 VUs, 155 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.6s/1m30s
#
# running (0m11.7s), 20/20 VUs, 157 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.7s/1m30s
#
# running (0m11.8s), 20/20 VUs, 158 complete and 0 interrupted iterations
# test   [===>----------------------------------] 20 VUs  0m11.8s/1m30s
#
# running (0m11.9s), 20/20 VUs, 158 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m11.9s/1m30s
#
# running (0m12.0s), 20/20 VUs, 158 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.0s/1m30s
#
# running (0m12.1s), 20/20 VUs, 162 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.1s/1m30s
#
# running (0m12.2s), 20/20 VUs, 164 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.2s/1m30s
#
# running (0m12.3s), 20/20 VUs, 164 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.3s/1m30s
#
# running (0m12.4s), 20/20 VUs, 164 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.4s/1m30s
#
# running (0m12.5s), 20/20 VUs, 166 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.5s/1m30s
#
# running (0m12.6s), 20/20 VUs, 169 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.6s/1m30s
#
# running (0m12.7s), 20/20 VUs, 170 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.7s/1m30s
#
# running (0m12.8s), 20/20 VUs, 172 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.8s/1m30s
#
# running (0m12.9s), 20/20 VUs, 173 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m12.9s/1m30s
#
# running (0m13.0s), 20/20 VUs, 175 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.0s/1m30s
#
# running (0m13.1s), 20/20 VUs, 177 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.1s/1m30s
#
# running (0m13.2s), 20/20 VUs, 177 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.2s/1m30s
#
# running (0m13.3s), 20/20 VUs, 178 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.3s/1m30s
#
# running (0m13.4s), 20/20 VUs, 181 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.4s/1m30s
#
# running (0m13.5s), 20/20 VUs, 182 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.5s/1m30s
#
# running (0m13.6s), 20/20 VUs, 184 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.6s/1m30s
#
# running (0m13.7s), 20/20 VUs, 184 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.7s/1m30s
#
# running (0m13.8s), 20/20 VUs, 185 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.8s/1m30s
#
# running (0m13.9s), 20/20 VUs, 187 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m13.9s/1m30s
#
# running (0m14.0s), 20/20 VUs, 188 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m14.0s/1m30s
#
# running (0m14.1s), 20/20 VUs, 191 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m14.1s/1m30s
#
# running (0m14.2s), 20/20 VUs, 191 complete and 0 interrupted iterations
# test   [====>---------------------------------] 20 VUs  0m14.2s/1m30s
#
# running (0m14.3s), 20/20 VUs, 193 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.3s/1m30s
#
# running (0m14.4s), 20/20 VUs, 196 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.4s/1m30s
#
# running (0m14.5s), 20/20 VUs, 197 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.5s/1m30s
#
# running (0m14.6s), 20/20 VUs, 197 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.6s/1m30s
#
# running (0m14.7s), 20/20 VUs, 200 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.7s/1m30s
#
# running (0m14.8s), 20/20 VUs, 201 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.8s/1m30s
#
# running (0m14.9s), 20/20 VUs, 203 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m14.9s/1m30s
#
# running (0m15.0s), 20/20 VUs, 203 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.0s/1m30s
#
# running (0m15.1s), 20/20 VUs, 204 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.1s/1m30s
#
# running (0m15.2s), 20/20 VUs, 206 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.2s/1m30s
#
# running (0m15.3s), 20/20 VUs, 210 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.3s/1m30s
#
# running (0m15.4s), 20/20 VUs, 210 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.4s/1m30s
#
# running (0m15.5s), 20/20 VUs, 210 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.5s/1m30s
#
# running (0m15.6s), 20/20 VUs, 211 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.6s/1m30s
#
# running (0m15.7s), 20/20 VUs, 215 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.7s/1m30s
#
# running (0m15.8s), 20/20 VUs, 215 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.8s/1m30s
#
# running (0m15.9s), 20/20 VUs, 216 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m15.9s/1m30s
#
# running (0m16.0s), 20/20 VUs, 217 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.0s/1m30s
#
# running (0m16.1s), 20/20 VUs, 220 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.1s/1m30s
#
# running (0m16.2s), 20/20 VUs, 220 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.2s/1m30s
#
# running (0m16.3s), 20/20 VUs, 220 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.3s/1m30s
#
# running (0m16.4s), 20/20 VUs, 223 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.4s/1m30s
#
# running (0m16.5s), 20/20 VUs, 226 complete and 0 interrupted iterations
# test   [=====>--------------------------------] 20 VUs  0m16.5s/1m30s
#
# running (0m16.6s), 20/20 VUs, 226 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m16.6s/1m30s
#
# running (0m16.7s), 20/20 VUs, 227 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m16.7s/1m30s
#
# running (0m16.8s), 20/20 VUs, 227 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m16.8s/1m30s
#
# running (0m16.9s), 20/20 VUs, 230 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m16.9s/1m30s
#
# running (0m17.0s), 20/20 VUs, 234 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.0s/1m30s
#
# running (0m17.1s), 20/20 VUs, 234 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.1s/1m30s
#
# running (0m17.2s), 20/20 VUs, 235 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.2s/1m30s
#
# running (0m17.3s), 20/20 VUs, 236 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.3s/1m30s
#
# running (0m17.4s), 20/20 VUs, 238 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.4s/1m30s
#
# running (0m17.5s), 20/20 VUs, 240 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.5s/1m30s
#
# running (0m17.6s), 20/20 VUs, 241 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.6s/1m30s
#
# running (0m17.7s), 20/20 VUs, 242 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.7s/1m30s
#
# running (0m17.8s), 20/20 VUs, 243 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.8s/1m30s
#
# running (0m17.9s), 20/20 VUs, 245 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m17.9s/1m30s
#
# running (0m18.0s), 20/20 VUs, 245 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.0s/1m30s
#
# running (0m18.1s), 20/20 VUs, 246 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.1s/1m30s
#
# running (0m18.2s), 20/20 VUs, 250 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.2s/1m30s
#
# running (0m18.3s), 20/20 VUs, 253 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.3s/1m30s
#
# running (0m18.4s), 20/20 VUs, 253 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.4s/1m30s
#
# running (0m18.5s), 20/20 VUs, 254 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.5s/1m30s
#
# running (0m18.6s), 20/20 VUs, 255 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.6s/1m30s
#
# running (0m18.7s), 20/20 VUs, 258 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.7s/1m30s
#
# running (0m18.8s), 20/20 VUs, 259 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.8s/1m30s
#
# running (0m18.9s), 20/20 VUs, 260 complete and 0 interrupted iterations
# test   [======>-------------------------------] 20 VUs  0m18.9s/1m30s
#
# running (0m19.0s), 20/20 VUs, 261 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.0s/1m30s
#
# running (0m19.1s), 20/20 VUs, 262 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.1s/1m30s
#
# running (0m19.2s), 20/20 VUs, 265 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.2s/1m30s
#
# running (0m19.3s), 20/20 VUs, 265 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.3s/1m30s
#
# running (0m19.4s), 20/20 VUs, 265 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.4s/1m30s
#
# running (0m19.5s), 20/20 VUs, 268 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.5s/1m30s
#
# running (0m19.6s), 20/20 VUs, 270 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.6s/1m30s
#
# running (0m19.7s), 20/20 VUs, 271 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.7s/1m30s
#
# running (0m19.8s), 20/20 VUs, 271 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.8s/1m30s
#
# running (0m19.9s), 20/20 VUs, 274 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m19.9s/1m30s
#
# running (0m20.0s), 20/20 VUs, 274 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.0s/1m30s
#
# running (0m20.1s), 20/20 VUs, 279 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.1s/1m30s
#
# running (0m20.2s), 20/20 VUs, 279 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.2s/1m30s
#
# running (0m20.3s), 20/20 VUs, 279 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.3s/1m30s
#
# running (0m20.4s), 20/20 VUs, 281 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.4s/1m30s
#
# running (0m20.5s), 20/20 VUs, 284 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.5s/1m30s
#
# running (0m20.6s), 20/20 VUs, 284 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.6s/1m30s
#
# running (0m20.7s), 20/20 VUs, 284 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.7s/1m30s
#
# running (0m20.8s), 20/20 VUs, 286 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.8s/1m30s
#
# running (0m20.9s), 20/20 VUs, 287 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m20.9s/1m30s
#
# running (0m21.0s), 20/20 VUs, 290 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m21.0s/1m30s
#
# running (0m21.1s), 20/20 VUs, 290 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m21.1s/1m30s
#
# running (0m21.2s), 20/20 VUs, 292 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m21.2s/1m30s
#
# running (0m21.3s), 20/20 VUs, 293 complete and 0 interrupted iterations
# test   [=======>------------------------------] 20 VUs  0m21.3s/1m30s
#
# running (0m21.4s), 20/20 VUs, 297 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.4s/1m30s
#
# running (0m21.5s), 20/20 VUs, 297 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.5s/1m30s
#
# running (0m21.6s), 20/20 VUs, 297 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.6s/1m30s
#
# running (0m21.7s), 20/20 VUs, 301 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.7s/1m30s
#
# running (0m21.8s), 20/20 VUs, 303 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.8s/1m30s
#
# running (0m21.9s), 20/20 VUs, 303 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m21.9s/1m30s
#
# running (0m22.0s), 20/20 VUs, 303 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.0s/1m30s
#
# running (0m22.1s), 20/20 VUs, 305 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.1s/1m30s
#
# running (0m22.2s), 20/20 VUs, 305 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.2s/1m30s
#
# running (0m22.3s), 20/20 VUs, 308 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.3s/1m30s
#
# running (0m22.4s), 20/20 VUs, 310 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.4s/1m30s
#
# running (0m22.5s), 20/20 VUs, 310 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.5s/1m30s
#
# running (0m22.6s), 20/20 VUs, 312 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.6s/1m30s
#
# running (0m22.7s), 20/20 VUs, 316 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.7s/1m30s
#
# running (0m22.8s), 20/20 VUs, 317 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.8s/1m30s
#
# running (0m22.9s), 20/20 VUs, 318 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m22.9s/1m30s
#
# running (0m23.0s), 20/20 VUs, 319 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.0s/1m30s
#
# running (0m23.1s), 20/20 VUs, 321 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.1s/1m30s
#
# running (0m23.2s), 20/20 VUs, 323 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.2s/1m30s
#
# running (0m23.3s), 20/20 VUs, 323 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.3s/1m30s
#
# running (0m23.4s), 20/20 VUs, 324 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.4s/1m30s
#
# running (0m23.5s), 20/20 VUs, 324 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.5s/1m30s
#
# running (0m23.6s), 20/20 VUs, 326 complete and 0 interrupted iterations
# test   [========>-----------------------------] 20 VUs  0m23.6s/1m30s
#
# running (0m23.7s), 20/20 VUs, 327 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m23.7s/1m30s
#
# running (0m23.8s), 20/20 VUs, 328 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m23.8s/1m30s
#
# running (0m23.9s), 20/20 VUs, 330 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m23.9s/1m30s
#
# running (0m24.0s), 20/20 VUs, 333 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.0s/1m30s
#
# running (0m24.1s), 20/20 VUs, 336 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.1s/1m30s
#
# running (0m24.2s), 20/20 VUs, 336 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.2s/1m30s
#
# running (0m24.3s), 20/20 VUs, 338 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.3s/1m30s
#
# running (0m24.4s), 20/20 VUs, 339 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.4s/1m30s
#
# running (0m24.5s), 20/20 VUs, 341 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.5s/1m30s
#
# running (0m24.6s), 20/20 VUs, 341 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.6s/1m30s
#
# running (0m24.7s), 20/20 VUs, 342 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.7s/1m30s
#
# running (0m24.8s), 20/20 VUs, 342 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.8s/1m30s
#
# running (0m24.9s), 20/20 VUs, 345 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m24.9s/1m30s
#
# running (0m25.0s), 20/20 VUs, 347 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.0s/1m30s
#
# running (0m25.1s), 20/20 VUs, 348 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.1s/1m30s
#
# running (0m25.2s), 20/20 VUs, 348 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.2s/1m30s
#
# running (0m25.3s), 20/20 VUs, 349 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.3s/1m30s
#
# running (0m25.4s), 20/20 VUs, 355 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.4s/1m30s
#
# running (0m25.5s), 20/20 VUs, 356 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.5s/1m30s
#
# running (0m25.6s), 20/20 VUs, 358 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.6s/1m30s
#
# running (0m25.7s), 20/20 VUs, 358 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.7s/1m30s
#
# running (0m25.8s), 20/20 VUs, 359 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.8s/1m30s
#
# running (0m25.9s), 20/20 VUs, 360 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m25.9s/1m30s
#
# running (0m26.0s), 20/20 VUs, 360 complete and 0 interrupted iterations
# test   [=========>----------------------------] 20 VUs  0m26.0s/1m30s
#
# running (0m26.1s), 20/20 VUs, 361 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.1s/1m30s
#
# running (0m26.2s), 20/20 VUs, 364 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.2s/1m30s
#
# running (0m26.3s), 20/20 VUs, 364 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.3s/1m30s
#
# running (0m26.4s), 20/20 VUs, 367 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.4s/1m30s
#
# running (0m26.5s), 20/20 VUs, 368 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.5s/1m30s
#
# running (0m26.6s), 20/20 VUs, 369 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.6s/1m30s
#
# running (0m26.7s), 20/20 VUs, 374 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.7s/1m30s
#
# running (0m26.8s), 20/20 VUs, 374 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.8s/1m30s
#
# running (0m26.9s), 20/20 VUs, 376 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m26.9s/1m30s
#
# running (0m27.0s), 20/20 VUs, 376 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.0s/1m30s
#
# running (0m27.1s), 20/20 VUs, 378 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.1s/1m30s
#
# running (0m27.2s), 20/20 VUs, 379 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.2s/1m30s
#
# running (0m27.3s), 20/20 VUs, 379 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.3s/1m30s
#
# running (0m27.4s), 20/20 VUs, 381 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.4s/1m30s
#
# running (0m27.5s), 20/20 VUs, 381 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.5s/1m30s
#
# running (0m27.6s), 20/20 VUs, 384 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.6s/1m30s
#
# running (0m27.7s), 20/20 VUs, 386 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.7s/1m30s
#
# running (0m27.8s), 20/20 VUs, 386 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.8s/1m30s
#
# running (0m27.9s), 20/20 VUs, 391 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m27.9s/1m30s
#
# running (0m28.0s), 20/20 VUs, 392 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m28.0s/1m30s
#
# running (0m28.1s), 20/20 VUs, 392 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m28.1s/1m30s
#
# running (0m28.2s), 20/20 VUs, 393 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m28.2s/1m30s
#
# running (0m28.3s), 20/20 VUs, 395 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m28.3s/1m30s
#
# running (0m28.4s), 20/20 VUs, 397 complete and 0 interrupted iterations
# test   [==========>---------------------------] 20 VUs  0m28.4s/1m30s
#
# running (0m28.5s), 20/20 VUs, 397 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m28.5s/1m30s
#
# running (0m28.6s), 20/20 VUs, 397 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m28.6s/1m30s
#
# running (0m28.7s), 20/20 VUs, 400 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m28.7s/1m30s
#
# running (0m28.8s), 20/20 VUs, 402 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m28.8s/1m30s
#
# running (0m28.9s), 20/20 VUs, 402 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m28.9s/1m30s
#
# running (0m29.0s), 20/20 VUs, 404 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.0s/1m30s
#
# running (0m29.1s), 20/20 VUs, 405 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.1s/1m30s
#
# running (0m29.2s), 20/20 VUs, 409 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.2s/1m30s
#
# running (0m29.3s), 20/20 VUs, 410 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.3s/1m30s
#
# running (0m29.4s), 20/20 VUs, 411 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.4s/1m30s
#
# running (0m29.5s), 20/20 VUs, 412 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.5s/1m30s
#
# running (0m29.6s), 20/20 VUs, 413 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.6s/1m30s
#
# running (0m29.7s), 20/20 VUs, 417 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.7s/1m30s
#
# running (0m29.8s), 20/20 VUs, 417 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.8s/1m30s
#
# running (0m29.9s), 20/20 VUs, 417 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m29.9s/1m30s
#
# running (0m30.0s), 20/20 VUs, 418 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m30.0s/1m30s
#
# running (0m30.1s), 20/20 VUs, 421 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m30.1s/1m30s
#
# running (0m30.2s), 20/20 VUs, 421 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m30.2s/1m30s
#
# running (0m30.3s), 20/20 VUs, 423 complete and 0 interrupted iterations
# test   [===========>--------------------------] 20 VUs  0m30.3s/1m30s
#
# running (0m30.4s), 20/20 VUs, 424 complete and 0 interrupted iterations
# ...
#
# running (1m22.1s), 20/20 VUs, 1165 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.1s/1m30s
#
# running (1m22.2s), 20/20 VUs, 1167 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.2s/1m30s
#
# running (1m22.3s), 20/20 VUs, 1168 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.3s/1m30s
#
# running (1m22.4s), 20/20 VUs, 1170 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.4s/1m30s
#
# running (1m22.5s), 20/20 VUs, 1170 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.5s/1m30s
#
# running (1m22.6s), 20/20 VUs, 1174 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.6s/1m30s
#
# running (1m22.7s), 20/20 VUs, 1174 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.7s/1m30s
#
# running (1m22.8s), 20/20 VUs, 1177 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.8s/1m30s
#
# running (1m22.9s), 20/20 VUs, 1178 complete and 0 interrupted iterations
# test   [=================================>----] 20 VUs  1m22.9s/1m30s
#
# running (1m23.0s), 20/20 VUs, 1179 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.0s/1m30s
#
# running (1m23.1s), 20/20 VUs, 1180 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.1s/1m30s
#
# running (1m23.2s), 20/20 VUs, 1181 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.2s/1m30s
#
# running (1m23.3s), 20/20 VUs, 1183 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.3s/1m30s
#
# running (1m23.4s), 20/20 VUs, 1183 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.4s/1m30s
#
# running (1m23.5s), 20/20 VUs, 1184 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.5s/1m30s
#
# running (1m23.6s), 20/20 VUs, 1187 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.6s/1m30s
#
# running (1m23.7s), 20/20 VUs, 1189 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.7s/1m30s
#
# running (1m23.8s), 20/20 VUs, 1190 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.8s/1m30s
#
# running (1m23.9s), 20/20 VUs, 1192 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m23.9s/1m30s
#
# running (1m24.0s), 20/20 VUs, 1192 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.0s/1m30s
#
# running (1m24.1s), 20/20 VUs, 1195 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.1s/1m30s
#
# running (1m24.2s), 20/20 VUs, 1198 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.2s/1m30s
#
# running (1m24.3s), 20/20 VUs, 1198 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.3s/1m30s
#
# running (1m24.4s), 20/20 VUs, 1199 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.4s/1m30s
#
# running (1m24.5s), 20/20 VUs, 1201 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.5s/1m30s
#
# running (1m24.6s), 20/20 VUs, 1202 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.6s/1m30s
#
# running (1m24.7s), 20/20 VUs, 1202 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.7s/1m30s
#
# running (1m24.8s), 20/20 VUs, 1202 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.8s/1m30s
#
# running (1m24.9s), 20/20 VUs, 1206 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m24.9s/1m30s
#
# running (1m25.0s), 20/20 VUs, 1207 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m25.0s/1m30s
#
# running (1m25.1s), 20/20 VUs, 1210 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m25.1s/1m30s
#
# running (1m25.2s), 20/20 VUs, 1211 complete and 0 interrupted iterations
# test   [==================================>---] 20 VUs  1m25.2s/1m30s
#
# running (1m25.3s), 20/20 VUs, 1211 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.3s/1m30s
#
# running (1m25.4s), 20/20 VUs, 1213 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.4s/1m30s
#
# running (1m25.5s), 20/20 VUs, 1216 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.5s/1m30s
#
# running (1m25.6s), 20/20 VUs, 1216 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.6s/1m30s
#
# running (1m25.7s), 20/20 VUs, 1216 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.7s/1m30s
#
# running (1m25.8s), 20/20 VUs, 1218 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.8s/1m30s
#
# running (1m25.9s), 20/20 VUs, 1219 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m25.9s/1m30s
#
# running (1m26.0s), 20/20 VUs, 1222 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.0s/1m30s
#
# running (1m26.1s), 20/20 VUs, 1222 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.1s/1m30s
#
# running (1m26.2s), 20/20 VUs, 1225 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.2s/1m30s
#
# running (1m26.3s), 20/20 VUs, 1226 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.3s/1m30s
#
# running (1m26.4s), 20/20 VUs, 1228 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.4s/1m30s
#
# running (1m26.5s), 20/20 VUs, 1228 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.5s/1m30s
#
# running (1m26.6s), 20/20 VUs, 1229 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.6s/1m30s
#
# running (1m26.7s), 20/20 VUs, 1232 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.7s/1m30s
#
# running (1m26.8s), 20/20 VUs, 1232 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.8s/1m30s
#
# running (1m26.9s), 20/20 VUs, 1234 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m26.9s/1m30s
#
# running (1m27.0s), 20/20 VUs, 1234 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.0s/1m30s
#
# running (1m27.1s), 20/20 VUs, 1238 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.1s/1m30s
#
# running (1m27.2s), 20/20 VUs, 1238 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.2s/1m30s
#
# running (1m27.3s), 20/20 VUs, 1238 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.3s/1m30s
#
# running (1m27.4s), 20/20 VUs, 1241 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.4s/1m30s
#
# running (1m27.5s), 20/20 VUs, 1242 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.5s/1m30s
#
# running (1m27.6s), 20/20 VUs, 1244 complete and 0 interrupted iterations
# test   [===================================>--] 20 VUs  1m27.6s/1m30s
#
# running (1m27.7s), 20/20 VUs, 1245 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m27.7s/1m30s
#
# running (1m27.8s), 20/20 VUs, 1246 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m27.8s/1m30s
#
# running (1m27.9s), 20/20 VUs, 1247 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m27.9s/1m30s
#
# running (1m28.0s), 20/20 VUs, 1249 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.0s/1m30s
#
# running (1m28.1s), 20/20 VUs, 1252 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.1s/1m30s
#
# running (1m28.2s), 20/20 VUs, 1253 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.2s/1m30s
#
# running (1m28.3s), 20/20 VUs, 1253 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.3s/1m30s
#
# running (1m28.4s), 20/20 VUs, 1256 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.4s/1m30s
#
# running (1m28.5s), 20/20 VUs, 1257 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.5s/1m30s
#
# running (1m28.6s), 20/20 VUs, 1257 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.6s/1m30s
#
# running (1m28.7s), 20/20 VUs, 1259 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.7s/1m30s
#
# running (1m28.8s), 20/20 VUs, 1259 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.8s/1m30s
#
# running (1m28.9s), 20/20 VUs, 1262 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m28.9s/1m30s
#
# running (1m29.0s), 20/20 VUs, 1264 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.0s/1m30s
#
# running (1m29.1s), 20/20 VUs, 1264 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.1s/1m30s
#
# running (1m29.2s), 20/20 VUs, 1265 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.2s/1m30s
#
# running (1m29.3s), 20/20 VUs, 1270 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.3s/1m30s
#
# running (1m29.4s), 20/20 VUs, 1272 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.4s/1m30s
#
# running (1m29.5s), 20/20 VUs, 1273 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.5s/1m30s
#
# running (1m29.6s), 20/20 VUs, 1273 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.6s/1m30s
#
# running (1m29.7s), 20/20 VUs, 1275 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.7s/1m30s
#
# running (1m29.8s), 20/20 VUs, 1275 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.8s/1m30s
#
# running (1m29.9s), 20/20 VUs, 1277 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m29.9s/1m30s
#
# running (1m30.0s), 20/20 VUs, 1278 complete and 0 interrupted iterations
# test   [====================================>-] 20 VUs  1m30.0s/1m30s
#
# running (1m30.1s), 19/20 VUs, 1279 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.2s), 17/20 VUs, 1281 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.3s), 17/20 VUs, 1281 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.4s), 15/20 VUs, 1283 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.5s), 14/20 VUs, 1284 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.6s), 11/20 VUs, 1287 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.7s), 06/20 VUs, 1292 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.8s), 05/20 VUs, 1293 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m30.9s), 05/20 VUs, 1293 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.0s), 05/20 VUs, 1293 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.1s), 03/20 VUs, 1295 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.2s), 02/20 VUs, 1296 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.3s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.4s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.5s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
# INFO[0092] ENDPOINT_NAME: llama-2-13b-chat-259c22c9-e25d-4661-94f1-0a1f891d8adb  source=console
#
# running (1m31.5s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
# INFO[0092] REGION: us-east-1                             source=console
#
# running (1m31.5s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
#      ✓ Post status is 200
#
#      checks.........................: 100.00% ✓ 1298      ✗ 0
#      data_received..................: 5.1 MB  56 kB/s
#      data_sent......................: 1.1 MB  13 kB/s
#      http_req_blocked...............: avg=3.26ms  min=1.13µs  med=2.26µs  max=213.87ms p(90)=3µs     p(95)=3.4µs
#      http_req_connecting............: avg=1.05ms  min=0s      med=0s      max=69.52ms  p(90)=0s      p(95)=0s
#      http_req_duration..............: avg=1.39s   min=1.23s   med=1.32s   max=2.16s    p(90)=1.65s   p(95)=1.72s
#        { expected_response:true }...: avg=1.39s   min=1.23s   med=1.32s   max=2.16s    p(90)=1.65s   p(95)=1.72s
#    ✓ http_req_failed................: 0.00%   ✓ 0         ✗ 1298
#      http_req_receiving.............: avg=68.25µs min=27.77µs med=61.62µs max=733.71µs p(90)=92.84µs p(95)=107.93µs
#      http_req_sending...............: avg=22.44µs min=11.01µs med=22.28µs max=61.03µs  p(90)=26.11µs p(95)=28.95µs
#      http_req_tls_handshaking.......: avg=2.18ms  min=0s      med=0s      max=143.97ms p(90)=0s      p(95)=0s
#      http_req_waiting...............: avg=1.39s   min=1.23s   med=1.32s   max=2.16s    p(90)=1.65s   p(95)=1.72s
#      http_reqs......................: 1298    14.180066/s
#      iteration_duration.............: avg=1.39s   min=1.23s   med=1.32s   max=2.16s    p(90)=1.65s   p(95)=1.72s
#      iterations.....................: 1298    14.180066/s
#      vus............................: 5       min=5       max=20
#      vus_max........................: 20      min=20      max=20
#
#
# running (1m31.5s), 01/20 VUs, 1297 complete and 0 interrupted iterations
# test ↓ [======================================] 20 VUs  1m30s
#
# running (1m31.5s), 00/20 VUs, 1298 complete and 0 interrupted iterations
# test ✓ [======================================] 20 VUs  1m30s
# Waiting for cloudwatch logs to be populated
# Waiting for query to complete ...
# Waiting for query to complete ...

# %% [markdown]
# We ran multiple benchmarks for different concurrent users, including 50, 75 and 100 concurrent users and `MAX_BATCH_TOTAL_TOKENS` (8192, 16384). The table below includes the thorughput (tokens/second), median latency (ms/token) and the queue time in ms (time the request was in the queue before it was processed).
#
# | Model | Concurrent Users | max batch tokens | Throughput  (token/second)| med. Latency (ms/token) | Queue Time (ms) |
# |-------|----------------|--------------------|--------------------------|-------------------------|--------------------|
# | Llama 13B | 50 | 8192 | 1419 tokens/second | 25.14 (ms/token) | 404ms |
# | Llama 13B | 75 | 8192 | 1561  tokens/second | 25.21 (ms/token) | 844ms |
# | Llama 13B | 100 | 8192 | 1634 tokens/second | 25.22 (ms/token) | 1553ms |
# | Llama 13B | 20 | 16384 | 757 tokens/second | 24.15 (ms/token) | 21ms |
# | Llama 13B | 50 | 16384 | 1400 tokens/second | 25.15 (ms/token) | 403ms |
# | Llama 13B | 75 | 16384 | 1540  tokens/second | 25.22 (ms/token) | 919ms |
# | Llama 13B | 100 | 16384 | 1622 tokens/second | 25.22 (ms/token) | 1521ms |
#
# We achieved a throughput between 1419 and 1634 tokens/second with a median latency between 25.14 and 25.21 ms/token, which is fast enough for real-time chat applications. We also see that the queue time increases with the number of concurrent users. This hints that we reached the limit of instance and should consider scaling out the number of instances.
#
# Comparing those results with the results from the ["Llama 2 on Amazon SageMaker a Benchmark"](https://huggingface.co/blog/llama-sagemaker-benchmark) we see that we were able to increase the throughput by 2-3x from 668 tokens/second to ~1600 tokens/second, while keeping the latency the same. Further improvements can be achieved by using quantization techniques like GPTQ or AWQ.

# %%
# !rm -rf text-generation-inference-tests

# %% [markdown]
# ## 6. Clean up
#
# To clean up, we can delete the model, endpoint and inference component for the hardware requirements.
#
# _Note: If you have issues deleting an endpoint with an attached inference component, see: https://repost.aws/es/questions/QUEiuS2we2TEKe9GUUYm67kQ/error-when-deleting-and-inference-endpoint-in-sagemaker_

# %%
# Delete Inference Component
llm_model.sagemaker_session.delete_inference_component(inference_component_name=inference_component)

# %% [markdown]
# we have to wait until the component is deleted before we can delete the endpoint. (can take 2minutes)

# %%
# Delete Model and Endpoint
llm.delete_model()
llm.delete_endpoint()
